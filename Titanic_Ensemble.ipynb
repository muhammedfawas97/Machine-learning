# %%
import pandas as pd
titanic=pd.read_csv('C:\\Users\\Dell\Downloads\\train.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic=titanic.drop(['Ticket','Cabin'],axis=1)
titanic=titanic.dropna()
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic=pd.concat([titanic,pd.get_dummies(titanic['Sex'])],axis=1)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic=pd.concat([titanic,pd.get_dummies(titanic['Embarked'])],axis=1)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
x=titanic[['Pclass','Age','female','SibSp','Parch','S','C','Q']]
y=titanic['Survived']

# %%
x
# Out:
#      Pclass   Age  female  SibSp  Parch  S  C  Q
# 0         3  22.0       0      1      0  1  0  0
# 1         1  38.0       1      1      0  0  1  0
# 2         3  26.0       1      0      0  1  0  0
# 3         1  35.0       1      1      0  1  0  0
# 4         3  35.0       0      0      0  1  0  0
# ..      ...   ...     ...    ...    ... .. .. ..
# 885       3  39.0       1      0      5  0  0  1
# 886       2  27.0       0      0      0  1  0  0
# 887       1  19.0       1      0      0  1  0  0
# 889       1  26.0       0      0      0  0  1  0
# 890       3  32.0       0      0      0  0  0  1
#
# [712 rows x 8 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 885    0
# 886    0
# 887    1
# 889    1
# 890    0
# Name: Survived, Length: 712, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#      Pclass   Age  female  SibSp  Parch  S  C  Q
# 472       2  33.0       1      1      2  1  0  0
# 432       2  42.0       1      1      0  1  0  0
# 666       2  25.0       0      0      0  1  0  0
# 30        1  40.0       0      0      0  0  1  0
# 291       1  19.0       1      1      0  0  1  0
# ..      ...   ...     ...    ...    ... .. .. ..
# 93        3  26.0       0      1      2  1  0  0
# 135       2  23.0       0      0      0  0  1  0
# 338       3  45.0       0      0      0  1  0  0
# 549       2   8.0       0      1      1  1  0  0
# 131       3  20.0       0      0      0  1  0  0
#
# [569 rows x 8 columns]

# %%
from sklearn.metrics import roc_curve,auc
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble.weight_boosting import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble.forest import RandomForestClassifier,ExtraTreesClassifier
n_estimators=100

models=[DecisionTreeClassifier(max_depth=3),BaggingClassifier(n_estimators=n_estimators),
       RandomForestClassifier(n_estimators=n_estimators),
       ExtraTreesClassifier(n_estimators=n_estimators),
        AdaBoostClassifier(n_estimators=n_estimators)
       ]
model_title=['DecisionTree','Bagging','RandomForest','ExgtraTrees','AdaBoost']

surv_preds,surv_prob,scores,fprs,tprs,thres=([] for i in range(6))

# %%
for i , model in enumerate(models):
    print('Fitting {}'.format(model_title[i]))
    cld=model.fit(x_train,y_train)
    surv_preds.append(model.predict(x_test))
    surv_prob.append(model.predict_proba(x_test))
    scores.append(model.score(x_test,y_test))
    fpr,tpr,threshold=roc_curve(y_test,surv_prob[i][:,1])
    fprs.append(fpr)
    tprs.append(tpr)
    thres.append(threshold)
    plt.title('ROC Curve')
    roc_auc=auc(fpr,tpr)
    plt.plot(fpr,tpr,'b',label='AUC=%.2f'%roc_auc)
    plt.legend(loc='lower right')
    plt.show()
# Out:
# Fitting DecisionTree
# Fitting Bagging
# Fitting RandomForest
# Fitting ExgtraTrees
# Fitting AdaBoost

# %%
for i,score in enumerate(scores):
    print('{0} with score {1:0.2f}'.format(model_title[i],score))
# Out:
# DecisionTree with score 0.73
# Bagging with score 0.77
# RandomForest with score 0.78
# ExgtraTrees with score 0.78
# AdaBoost with score 0.80
